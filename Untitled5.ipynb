# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df1 = pd.read_excel('B0006.xlsx')
df2 = pd.read_excel('B0005.xlsx')
df3 = pd.read_excel('B0007.xlsx')

# %%
df4=pd.merge(df1,df2,how='outer')

# %%
df=pd.merge(df4,df3,how='outer')
# Out:
# C:\Users\mitra\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py:1205: UserWarning: You are merging on int and float columns where the float values are not equal to their int representation.
#   warnings.warn(

# %%
df
# Out:
#        Voltage_measured  Current_measured  Temperature_measured  \
# 0              3.966528         -2.014242             24.366226
# 1              3.945886         -2.008730             24.515123
# 2              3.930354         -2.013381             24.676053
# 3              3.917440         -2.011192             24.853025
# 4              3.906451         -2.010007             25.018929
# ...                 ...               ...                   ...
# 21631          2.761255         -1.992264             37.697455
# 21632          2.670529         -1.990352             37.815045
# 21633          2.542965         -1.989135             37.966597
# 21634          2.362188         -1.988622             38.171399
# 21635          2.135620         -1.990881             38.426047
#
#        Current_charge  Voltage_charge      Time  Capacity  cycle       type  \
# 0               1.999           3.070    35.703  2.035338      1  discharge
# 1               1.999           3.045    53.781  2.035338      1  discharge
# 2               1.999           3.026    71.922  2.035338      1  discharge
# 3               1.999           3.011    90.094  2.035338      1  discharge
# 4               1.999           3.002   108.281  2.035338      1  discharge
# ...               ...             ...       ...       ...    ...        ...
# 21631           2.000           1.846  3329.140  1.836828     35  discharge
# 21632           2.000           1.760  3338.750  1.836828     35  discharge
# 21633           2.000           1.645  3348.562  1.836828     35  discharge
# 21634           2.000           1.481  3358.437  1.836828     35  discharge
# 21635           2.000           1.264  3368.187  1.836828     35  discharge
#
#        ambient_temperature  time Battery
# 0                       24  2008   B0006
# 1                       24  2008   B0006
# 2                       24  2008   B0006
# 3                       24  2008   B0006
# 4                       24  2008   B0006
# ...                    ...   ...     ...
# 21631                   24  2008   B0007
# 21632                   24  2008   B0007
# 21633                   24  2008   B0007
# 21634                   24  2008   B0007
# 21635                   24  2008   B0007
#
# [21636 rows x 12 columns]

# %%
df=df.drop(['type'], axis=1)

# %%
df.isnull().sum()
# Out:
# Voltage_measured        0
# Current_measured        0
# Temperature_measured    0
# Current_charge          0
# Voltage_charge          0
# Time                    0
# Capacity                0
# cycle                   0
# ambient_temperature     0
# time                    0
# Battery                 0
# dtype: int64

# %%
X = df.drop('Battery',axis=1)
y = df['Battery']

# %%
X
# Out:
#        Voltage_measured  Current_measured  Temperature_measured  \
# 0              3.966528         -2.014242             24.366226
# 1              3.945886         -2.008730             24.515123
# 2              3.930354         -2.013381             24.676053
# 3              3.917440         -2.011192             24.853025
# 4              3.906451         -2.010007             25.018929
# ...                 ...               ...                   ...
# 21631          2.761255         -1.992264             37.697455
# 21632          2.670529         -1.990352             37.815045
# 21633          2.542965         -1.989135             37.966597
# 21634          2.362188         -1.988622             38.171399
# 21635          2.135620         -1.990881             38.426047
#
#        Current_charge  Voltage_charge      Time  Capacity  cycle  \
# 0               1.999           3.070    35.703  2.035338      1
# 1               1.999           3.045    53.781  2.035338      1
# 2               1.999           3.026    71.922  2.035338      1
# 3               1.999           3.011    90.094  2.035338      1
# 4               1.999           3.002   108.281  2.035338      1
# ...               ...             ...       ...       ...    ...
# 21631           2.000           1.846  3329.140  1.836828     35
# 21632           2.000           1.760  3338.750  1.836828     35
# 21633           2.000           1.645  3348.562  1.836828     35
# 21634           2.000           1.481  3358.437  1.836828     35
# 21635           2.000           1.264  3368.187  1.836828     35
#
#        ambient_temperature  time
# 0                       24  2008
# 1                       24  2008
# 2                       24  2008
# 3                       24  2008
# 4                       24  2008
# ...                    ...   ...
# 21631                   24  2008
# 21632                   24  2008
# 21633                   24  2008
# 21634                   24  2008
# 21635                   24  2008
#
# [21636 rows x 10 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
model = DecisionTreeClassifier()

# %%
model.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
base_pred = model.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix,classification_report,plot_confusion_matrix

# %%
confusion_matrix(y_test,base_pred)
# Out:
# array([[2071,    0,    0],
#        [   0, 2273,    0],
#        [   0,    1, 2146]], dtype=int64)

# %%
plot_confusion_matrix(model,X_test,y_test)
# Out:
# C:\Users\mitra\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)

# %%
print(classification_report(y_test,base_pred))
# Out:
#               precision    recall  f1-score   support
#
#        B0005       1.00      1.00      1.00      2071
#        B0006       1.00      1.00      1.00      2273
#        B0007       1.00      1.00      1.00      2147
#
#     accuracy                           1.00      6491
#    macro avg       1.00      1.00      1.00      6491
# weighted avg       1.00      1.00      1.00      6491

# %%
model.feature_importances_
# Out:
# array([0.        , 0.50431084, 0.        , 0.49568916, 0.        ,
#        0.        , 0.        , 0.        , 0.        , 0.        ])

# %%
pd.DataFrame(index=X.columns,data=model.feature_importances_,columns=['Feature Importance'])
# Out:
#                       Feature Importance
# Voltage_measured                0.000000
# Current_measured                0.504311
# Temperature_measured            0.000000
# Current_charge                  0.495689
# Voltage_charge                  0.000000
# Time                            0.000000
# Capacity                        0.000000
# cycle                           0.000000
# ambient_temperature             0.000000
# time                            0.000000

# %%
from sklearn.tree import plot_tree

# %%
plt.figure(figsize=(12,8))
plot_tree(model);

# %%
plt.figure(figsize=(12,8),dpi=200)
plot_tree(model,filled=True,feature_names=X.columns);
